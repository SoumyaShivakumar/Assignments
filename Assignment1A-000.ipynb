# %% [markdown]
# <a href="https://colab.research.google.com/github/SoumyaShivakumar/Assignments/blob/master/Assignment1A-000.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# import the necessary packages
import numpy as np
from urllib.request import urlopen
import cv2
from matplotlib import pyplot as plt

# METHOD #1: OpenCV, NumPy, and urllib
def url_to_image(url):
	# download the image, convert it to a NumPy array, and then read
	# it into OpenCV format
	resp = urlopen(url)
	image = np.asarray(bytearray(resp.read()), dtype="uint8")
	image = cv2.imdecode(image, cv2.IMREAD_COLOR)
 
	# return the image
	return image

# %%
image = url_to_image("https://fontsarena-cd5e.kxcdn.com/wp-content/uploads/2019/04/helvetica-now-font-400x364.png")

# %%
from google.colab.patches import cv2_imshow
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=400x364 at 0x7FAD0FFAC128>

# %%
edges = cv2.Canny(image,100,200)

# %%
cv2_imshow(edges)
# Out:
# <PIL.Image.Image image mode=L size=400x364 at 0x7FAD0F308CF8>

# %%
#kernel = Sharpened verical edges (sort of)
kernel = np.float32([[1,1,-1],[1,0,-1],[1,-1,-1]])

dst = cv2.filter2D(image,-1,kernel)
cv2_imshow(dst)
# Out:
# <PIL.Image.Image image mode=RGB size=400x364 at 0x7FAD0DA43828>

# %%
#kernel = Sharpen Kernel
kernel = np.float32([[1,-0,-1],[0,-1,1],[-1,0,1]])

dst = cv2.filter2D(image,-1,kernel)
cv2_imshow(dst)
# Out:
# <PIL.Image.Image image mode=RGB size=400x364 at 0x7FAD0DA1DE10>

# %%
#kernel = Blured image
kernel = np.float32([[1,0,-1],[0,1,0],[-1,0,1]])

dst = cv2.filter2D(image,-1,kernel)
cv2_imshow(dst)
# Out:
# <PIL.Image.Image image mode=RGB size=400x364 at 0x7FAD0DA35278>

# %%
#kernel = Horizantal edges 1
kernel = np.float32([[-1,-1,-1],[0,0,0],[1,1,1]])

dst = cv2.filter2D(image,-1,kernel)
cv2_imshow(dst)
# Out:
# <PIL.Image.Image image mode=RGB size=400x364 at 0x7FAD0DA437F0>

# %%
#kernel = Horizantal edges 2
kernel = np.float32([[1,1,1],[0,0,0],[-1,-1,-1]])

dst = cv2.filter2D(image,-1,kernel)
cv2_imshow(dst)
# Out:
# <PIL.Image.Image image mode=RGB size=400x364 at 0x7FAD0DA35400>

# %%
#kernel = indentical image1
kernel = np.float32([[1,1,1],[0,1,0],[-1,-1,-1]])

dst = cv2.filter2D(image,-1,kernel)
cv2_imshow(dst)
# Out:
# <PIL.Image.Image image mode=RGB size=400x364 at 0x7FAD0DA3E588>

# %%
#kernel = indentical image2
kernel = np.float32([[-1,-1,-1],[0,1,0],[1,1,1]])

dst = cv2.filter2D(image,-1,kernel)
cv2_imshow(dst)
# Out:
# <PIL.Image.Image image mode=RGB size=400x364 at 0x7FAD0DA405C0>

# %%
#kernel = Angular (sort of)
kernel = np.float32([[1,1,1],[0,0,0],[-1,-1,-1]])

dst = cv2.filter2D(image,-1,kernel)
cv2_imshow(dst)
print()
kernel = np.float32([[1,0,-1],[0,-1,0],[1,0,-1]])

dst2 = cv2.filter2D(dst,-1,kernel)
cv2_imshow(dst2)
# Out:
# <PIL.Image.Image image mode=RGB size=400x364 at 0x7FAD0DA4E400>
# <PIL.Image.Image image mode=RGB size=400x364 at 0x7FAD0DA4E438>
